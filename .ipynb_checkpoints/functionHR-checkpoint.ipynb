# %%
from astropy.io import fits
import os
import pandas as pd
import glob
import numpy as np
from astropy import units as u

# %%
iso = pd.read_csv('../please.txt', delim_whitespace=True)
# importing the required module
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1,figsize=(15, 15))

plt.plot(iso["Bmag"] - iso["Vmag"], iso["Vmag"] + 14.8,'_', markersize = 8)

plt.gca().invert_yaxis()

plt.xlim(-0.3,1.6)
plt.ylim(24,12)

  
# function to show the plot
plt.show()

# %%
iso1 = pd.read_csv('../thanks.txt', delim_whitespace=True)
# importing the required module
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1,figsize=(15, 15))

plt.plot(iso1["Bmag"] - iso1["Vmag"], iso1["Vmag"] + 14.8,'_', markersize = 8)

plt.gca().invert_yaxis()

plt.xlim(-0.3,1.6)
plt.ylim(24,12)

  
# function to show the plot
plt.show()

# %%
iso1
# Out:
#          Zini   MH   logAge      Mini   int_IMF   Mass   logL   logTe   logg  \
# 0    0.000491 -1.5  9.93952  0.090000  1.081690  0.090 -3.186  3.4745  5.428
# 1    0.000491 -1.5  9.93952  0.100000  1.171106  0.100 -2.896  3.5159  5.349
# 2    0.000491 -1.5  9.93952  0.120000  1.319315  0.120 -2.610  3.5471  5.267
# 3    0.000491 -1.5  9.93952  0.140000  1.438453  0.140 -2.430  3.5624  5.215
# 4    0.000491 -1.5  9.93952  0.149027  1.485197  0.149 -2.364  3.5671  5.196
# ..        ...  ...      ...       ...       ...    ...    ...     ...    ...
# 215  0.000491 -1.5  9.93952  0.890577  2.446735  0.771  3.396  3.6077  0.312
# 216  0.000491 -1.5  9.93952  0.890578  2.446735  0.756  3.444  3.6030  0.237
# 217  0.000491 -1.5  9.93952  0.890579  2.446735  0.740  3.469  3.6004  0.192
# 218  0.000491 -1.5  9.93952  0.890580  2.446735  0.722  3.485  3.5990  0.160
# 219  0.000491 -1.5  9.93952  0.890583  2.446736  0.553 -9.999  4.0000  1.707
#
#      label  ...         Z  mbolmag    Umag    Bmag    Vmag    Rmag    Imag  \
# 0        1  ...  0.000494   12.734  20.178  17.420  15.418  13.704  12.064
# 1        1  ...  0.000494   12.009  17.618  15.669  13.819  12.534  11.320
# 2        1  ...  0.000494   11.295  15.810  14.306  12.673  11.562  10.596
# 3        1  ...  0.000494   10.845  14.898  13.573  12.053  11.011  10.142
# 4        1  ...  0.000494   10.681  14.597  13.327  11.842  10.819   9.979
# ..     ...  ...       ...      ...     ...     ...     ...     ...     ...
# 215      8  ...  0.000366   -3.720   0.778  -0.951  -2.681  -3.588  -4.313
# 216      8  ...  0.000366   -3.840   0.888  -0.934  -2.725  -3.667  -4.415
# 217      8  ...  0.000366   -3.901   0.960  -0.916  -2.742  -3.705  -4.466
# 218      8  ...  0.000366   -3.942   1.004  -0.905  -2.753  -3.730  -4.500
# 219      9  ...  0.000366   29.767  29.789  30.041  30.090  30.083  30.075
#
#        Jmag    Hmag    Kmag
# 0    10.745  10.436  10.335
# 1    10.162   9.702   9.560
# 2     9.549   9.026   8.861
# 3     9.147   8.604   8.429
# 4     8.999   8.451   8.273
# ..      ...     ...     ...
# 215  -5.318  -6.104  -6.219
# 216  -5.447  -6.251  -6.372
# 217  -5.514  -6.328  -6.452
# 218  -5.557  -6.376  -6.503
# 219  30.120  30.117  30.132
#
# [220 rows x 36 columns]

# %%
x1
background = pd.read_csv("tables/UBVRI.csv")
x1 = background['Bmag'] - background['Vmag']
y1 = background['Vmag']
background = background

# %%
background = pd.read_csv("tables/AAVSO.csv")
x1 = x1.append( background['Bmag'] - background['Vmag'])
y1 = y1.append( background['Vmag'])

# %%
result.to_csv("crossbase.csv")

# %%
x1 = np.loadtxt('x.txt')

# %%
y1 = np.loadtxt('y.txt')

# %%
np.savetxt("x.txt", x1, delimiter =", ")

# %%
# importing the required module
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
# importing modules
import numpy as np
import matplotlib.pyplot as plt
from astropy.visualization.mpl_normalize import ImageNormalize
from astropy.visualization import SqrtStretch
from matplotlib.patches import Arrow, Circle

def plot_HR(x,y,distance,title,label):
    fig, ax = plt.subplots(figsize=(12, 9))
    
    
    scatter = ax.scatter(x1, y1,s=6, color = "#d4d4d4" )
    scatter1 = ax.scatter(x, y,s=8, c=distance, cmap='viridis')
    scatter = ax.scatter(iso1["Bmag"] - iso1["Vmag"], iso1["Vmag"]+ 15.1, s=30, marker = "_", color = '#FF6759')
    
    plt.colorbar(scatter1,label = 'Distance to center of M3(arcmin)')
    
    
    #ax = scatter.axes
    size = len(x)
    #ax.text(-0.25, 13.8, f"Database Size = {size}",fontsize=12)
    ax.text(1, 12, f"Database Size = {size}")
    ax.yaxis.grid(color='#d4d4d4', linestyle='dashed')
    ax.xaxis.grid(color='#d4d4d4', linestyle='dashed')
    ax.set_facecolor('#fefefe')
    plt.xlabel('B-V',fontsize=16)
    plt.ylabel('V',fontsize=16)
    plt.gca().invert_yaxis()
    
    ax.scatter([1.247],[13.038], s = 80, color='red', edgecolor='black')
    ax.text(1.3, 13.158, f"Reference star",color='red', backgroundcolor="white")
    ax.legend(['All Stars Cross Database', label, 'isochrone'], markerscale = 2, fontsize=12)
    #plt.title(title,fontsize=16)
    plt.xlim(-0.3,1.6)
    plt.ylim(22,10)
    plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=None)
    plt.savefig(f"figures/{label}.png",bbox_inches='tight', pad_inches=0)
    #plt.show()

# %%
result = pd.read_csv("result.csv")
result = result[result["distance"] < 8.1]
x = result['Bmag'] - result['Vmag']
y = result['Vmag']
distance = result['distance']

# %%
result = result[result["distance"] < 8.1]

# %%
def generate(table,title,label):
    result = pd.read_csv(table)
    x = result['Bmag'] - result['Vmag']
    y = result['Vmag']
    distance = result['distance']
    plot_HR(x,y,distance,title,label)

# %%
result
# Out:
#      Unnamed: 0  Unnamed: 0_B  Unnamed: 0.1_B  id_B  xcentroid_B  ycentroid_B  \
# 8        421597           282             282   283  1853.871717   816.726191
# 10       424585           284             284   285  1853.371549   816.785329
# 15       542704           363             363   364  1548.624229  1084.311463
# 16       542705           363             363   364  1548.624229  1084.311463
# 19       569619           381             381   382  1583.278290  1130.001694
# ..          ...           ...             ...   ...          ...          ...
# 239     1336734           894             894   895  2110.567533  1929.300033
# 243     1368130           915             915   916   970.986979  1992.617701
# 244     1368133           915             915   916   970.986979  1992.617701
# 245     1369624           916             916   917   971.499254  1992.592917
# 246     1369627           916             916   917   971.499254  1992.592917
#
#      sharpness_B  roundness1_B  roundness2_B  npix_B  ...  sky_V  \
# 8       0.726493     -0.167037      0.147036      25  ...    0.0
# 10      0.369516     -0.132020      0.028104      25  ...    0.0
# 15      0.313136     -0.112097     -0.160858      25  ...    0.0
# 16      0.313136     -0.112097     -0.160858      25  ...    0.0
# 19      0.365908     -0.031886     -0.006622      25  ...    0.0
# ..           ...           ...           ...     ...  ...    ...
# 239     0.397382      0.014661      0.165993      25  ...    0.0
# 243     0.225906      0.014905      0.690939      25  ...    0.0
# 244     0.225906      0.014905      0.690939      25  ...    0.0
# 245     0.361095      0.161052      0.554280      25  ...    0.0
# 246     0.361095      0.161052      0.554280      25  ...    0.0
#
#            peak_V     flux_V      mag_V       x_rad       y_rad       rad  \
# 8     2681.789628   4.341773  12.916004  286.016033 -652.808629  7.226942
# 10    2681.789628   4.341773  12.916004  286.016033 -652.808629  7.226942
# 15    1204.229297   2.202406  13.717805  -19.348041 -385.490029  3.913789
# 16    1116.537410   1.836578  13.932389  -19.210207 -386.097050  3.919867
# 19    1514.721399   2.441615  13.596000   15.222797 -339.645339  3.447461
# ..            ...        ...        ...         ...         ...       ...
# 239  44758.931226  61.179057   9.790790  542.639166  459.390303  7.209367
# 243   2026.856363   2.964988  13.366572 -596.609554  521.164573  8.032746
# 244   2048.590400   2.905319  13.390588 -596.584585  520.834586  8.030354
# 245   2026.856363   2.964988  13.366572 -596.609554  521.164573  8.032746
# 246   2048.590400   2.905319  13.390588 -596.584585  520.834586  8.030354
#
#      distance       Vmag       Bmag
# 8    7.226942  12.916004  13.965892
# 10   7.226942  12.916004  14.333704
# 15   3.913789  13.717805  14.422340
# 16   3.919867  13.932389  14.422340
# 19   3.447461  13.596000  13.957718
# ..        ...        ...        ...
# 239  7.209367   9.790790  10.854608
# 243  8.032746  13.366572  14.513444
# 244  8.030354  13.390588  14.513444
# 245  8.032746  13.366572  14.020833
# 246  8.030354  13.390588  14.020833
#
# [223 rows x 33 columns]

# %%
plot_HR(x,y,distance,"UBVRI photometry in 48 globular clusters (Stetson+, 2019)", "ARCSAT,2023")

# %%
5 * np.log10(10.249*10**3)-5
# Out:
# 15.053407465657216

# %%
"tables/AAVSO.csv", "AAVSO Photometric All Sky Survey (APASS) DR9 (Henden+, 2016)", "Henden+, 2016"
"tables/BVI.csv", "BVI photometric variability survey of M3 (Hartman+, 2005)", "Hartman+, 2005"
"tables/Gaia.csv","Gaia EDR3 and Johnson-Kron-Cousins standards (Pancino+, 2022)","Pancino+, 2022"
"tables/RR.csv","RR Lyrae variables in NGC 5272 (Cacciari+, 2005)","Cacciari+, 2005"
"tables/BVI2006.csv","BVI(c) light curves of variables in M3 (Benko+, 2006)","Benko+, 2006"
"tables/UBVRI.csv","UBVRI photometry in 48 globular clusters (Stetson+, 2019)", "Stetson+, 2019"

# %%
 generate("result.csv","UBVRI photometry in 48 globular clusters (Stetson+, 2019)", "Stetson+, 2019")

# %%
result['distance']
# Out:
# 0        9.198871
# 1        9.193960
# 2        9.183098
# 3        9.193479
# 4        9.177490
#            ...
# 62726    9.145526
# 62727    9.151067
# 62728    9.150065
# 62729    9.180340
# 62730    9.202859
# Name: distance, Length: 62731, dtype: float64

# %%
generate("result.csv","Color Magnitude Diagram of M3", "ARCSAT,2023")

# %%
result.to_csv("result.csv")

# %%
result = result[result["distance"] < 8.1]

# %%
# importing the required module
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1,figsize=(15, 15))
ax.set_aspect('equal')
# x axis values
x = result["xcentroid_V"]
# corresponding y axis values
y = result["ycentroid_V"]


scatter = ax.scatter(x, y,s=60, c= result["distance"] , cmap='viridis', marker = "o", facecolor = "white", edgecolor="white")
circle1 = plt.Circle((1568, 1470), 200,  fill=False, lw=1, edgecolor='black')
circle2 = plt.Circle((1568, 1470), 600, fill=False, lw=1, edgecolor='black')


ax.add_patch(circle1)
ax.add_patch(circle2)



# naming the x axis
plt.xlabel('x')
# naming the y axis
plt.ylabel('y')
plt.xlim(800,2350)
plt.ylim(700,2250)
fig.savefig('temp.png', transparent=True)
# function to show the plot
plt.show()
